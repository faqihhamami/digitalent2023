# %%
from matematika.volume import kubus
from matematika.aritmatika import jumlah

# %%
hasil = kubus(2)
print(hasil)
# Out:
# 8

# %%
jumlah(4,3)
# Out:
# 7

# %%
import matematika

# %%
hasil = matematika.volume.tabung(2,5)
print(hasil)
# Out:
# 62.800000000000004

# %% [markdown]
# ## Emoji Package

# %%
import emoji

# %%
print(emoji.emojize('Python is :thumbs_up:'))
# Out:
# Python is 👍

# %%
from emoji import emojize
print(emojize('Python is fun :red_heart:'))
# Out:
# Python is fun ❤
