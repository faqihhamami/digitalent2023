# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
print("hello")
# Out:
# hello

# %%
import aritmatika

nilai1 = 10
nilai2 = 15

hasil = aritmatika.jumlah(nilai1, nilai2)
print(f'hasil penjumlahan adalah {hasil}')
# Out:
# hasil penjumlahan adalah 25

# %%
from aritmatika import jumlah, kali

print(jumlah(2,3))

print(kali(3,3))
# Out:
# 5
# 9

# %% [markdown]
# ## Lab 1
#
# - Buatlah modul suhu yang menyimpan fungsi konversi suhu celcius, farenheit, kelvin
# - Buat file baru dan lakukan konversi dari 3 fungsi yang dibuat

# %%
from suhu import cel_to_far, cel_to_kel, far_to_cel

# %%
print(f"konversi celcius ke farenheit {cel_to_far(10)}")
# Out:
# konversi celcius ke farenheit 50.0

# %%
print(f"konversi farenheit ke celcius {far_to_cel(50)}")
# Out:
# konversi farenheit ke celcius 10.0

# %% [markdown]
# ## Lab 2
# Buatlah modul luas bangun datar dan coba panggil fungsi2 di modul tsb

# %% [markdown]
# ## Lab 3
#
# Buatlah modul yang mengakomodir perhitungan
#
#     bilangan asli
#     bilangan prima
#     Fibonacci
#     n faktorial
#
# input numeric, misal angka 5 akan manampilkan 5 digit pertama atau perhitungan rumusnya
#
#     bilangan asli : 1,2,3,4,5
#     bilangan prima : 2,3,5,7,11
#     Fibonacci : 1,1,2,3,5
#     n faktorial : 5! => 120

# %%
# built-in module
import math

# %%
math.cos(30)
# Out:
# 0.15425144988758405

# %% [markdown]
# ## Python Package
#
# - kamis 10.30 - 12.00, 13-14.30
# - jumat 13.00 - 14.30, 15.30-17.00
