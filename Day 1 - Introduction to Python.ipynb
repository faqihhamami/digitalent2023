# %% [markdown]
# ## Pengenalan Python

# %%
print("selamat sore")
# Out:
# selamat sore

# %%
2 + 5
# Out:
# 7

# %%
print('selamat sore')
# Out:
# selamat sore

# %%
it's my laptop
dia adalah mahasiswa "spesial"

# %%
print('it\'s my laptop')
# Out:
# it's my laptop

# %%
print("it's my laptop")
# Out:
# it's my laptop

# %%
print('dia adalah mahasiswa "spesial" ')
# Out:
# dia adalah mahasiswa "spesial"

# %%
print("nemanampilkan karakter \\")
# Out:
# nemanampilkan karakter \

# %% [markdown]
# ### Lab 1
# tampilkan 2 kalimat ini
# - \n adalah contoh escape untuk enter
# - penggunaan \ atau single "

# %%
print("\\n adalah contoh escape untuk enter")
# Out:
# \n adalah contoh escape untuk enter

# %%
print("penggunaan \\ atau single \"")
# Out:
# penggunaan \ atau single "

# %% [markdown]
# ### Parameter `end, sep`

# %%
print("ini baris ke-1", end=".. ")
print("ini baris ke-2")
# Out:
# ini baris ke-1.. ini baris ke-2

# %%
print("ini budi", "ini tono", "ini andi", sep="-")
# Out:
# ini budi-ini tono-ini andi

# %% [markdown]
# # Variabel dan Tipe Data

# %%
nama = "Tono"
umur = 24
Laki = True
berat = 70.5

# %%
print(type(nama))
print(type(umur))
print(type(Laki))
print(type(berat))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
print("selamat pagi",nama,"yang umurnya",umur,"dan beratnya ",berat )
# Out:
# selamat pagi Tono yang umurnya 24 dan beratnya  70.5

# %% [markdown]
# ## Teknik Printing

# %%
# teknik 1
print("selamat pagi {} yang umurnya {} dan beratnya {}".format(nama, umur, berat))
# Out:
# selamat pagi Tono yang umurnya 24 dan beratnya 70.5

# %%
# teknik 2
print(f"selamat pagi {nama} yang umurnya {umur} dan beratnya {berat}")
# Out:
# selamat pagi Tono yang umurnya 24 dan beratnya 70.5

# %% [markdown]
# ### Lab 2
#
# - Buatlah 4 variabel yang isinya adalah `NIM`, `Nama`, `Alamat`, `HP`
#
# - Tampilkan `NIM saya adalah XX dengan nama XX yang beralamat XX dan XX adalah No HP saya `

# %% [markdown]
# # Aritmatika

# %%
a = 3
b = 2

# %%
a+b
# Out:
# 5

# %%
a-b
# Out:
# 1

# %%
a*b
# Out:
# 6

# %%
a/b
# Out:
# 1.5

# %%
a**b
# Out:
# 9

# %%
a%b # 3:2
# Out:
# 1

# %% [markdown]
# ## Lab 3
# a = 3
# b = 5
#
# Buatlah program untuk menghitung 2 variabel dan tampilkan hasilnya seperti ini
# - Hasil penjumlahan 3 dan 5 adalah 7
# - Hasil pengurangan a dan b adalah c
# - Hasil perklaian a dan b adalah c
# - Hasil pembagian a dan b adalah c
# - Hasil sisa bagi a dan b adalah c
# - Hasil pangkat a dan b adalah c

# %% [markdown]
# ## Lab 4
#
# 1. Buatlah program untuk menghitung luas segitiga
# 2. Buatlah program untuk menghitung luas persegi
